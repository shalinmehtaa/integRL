# %%
import pandas as pd

# %%
df = pd.read_csv("../integrl/checkpoints/SFT_GSM8K_LR3e5_WD001_BS4_GA8_GL1_E1_T0_TP095/metrics.csv")

# %%
df.tail()
# Out:
#      step  train_loss  ema_loss  val_metric  grad_norm     tok_per_s  \
# 748   749    0.365234  0.450404    0.328125   0.663813  10406.989431
# 749   750    0.404297  0.448099    0.328125   0.710543  12748.090323
# 750   751    0.605469  0.455967    0.328125   0.847391   9828.101852
# 751   752    0.337891  0.450063    0.328125   0.904605  11519.401143
# 752   753    0.427734  0.448947    0.328125   0.253766   8565.518069
#
#      elapsed_s
# 748   0.121841
# 749   0.170065
# 750   0.117622
# 751   0.128826
# 752   0.186795

# %%
# df.train_loss.plot()
df.ema_loss.plot();

# %%
df.val_metric.plot();
