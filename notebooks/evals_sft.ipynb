# %%
import pandas as pd

# %%
df = pd.read_csv("../integrl/checkpoints/SFT_GSM8K_LR2e5_WD001_BS4_GA4_GL1_E1_T0_TP095/metrics.csv")

# %%
# df = df[-753:].reset_index(drop=True)

# %%
# df.to_csv("../integrl/checkpoints/SFT_GSM8K_LR2e5_WD001_BS4_GA4_GL1_E1_T0_TP095/metrics.csv", index=False)

# %%
# df.train_loss.plot()
df.ema_loss.plot();

# %%
df.val_metric.plot();
